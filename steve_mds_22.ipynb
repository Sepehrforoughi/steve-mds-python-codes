# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.linspace(-1.5, 1.5, 301) # initial conditions span
X1, X2 = np.meshgrid(a,a) # coordinate matrices
dx1 = X1 - X1**2 # x1 dot
dx2 = X1 + X2 # x2 dot
plt.streamplot(X1, X2, dx1, dx2, density= 2)
plt.grid('on')
